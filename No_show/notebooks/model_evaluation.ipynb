# %% [markdown]
# # Evaluate model performance on test set

# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import relplot as rp
from sklearn.calibration import calibration_curve
from sklearn.metrics import (
    precision_recall_curve,
    precision_score,
    recall_score,
    roc_auc_score,
    roc_curve,
)
from sklearn.model_selection import train_test_split

# %%
with open("../output/models/no_show_model_cv.pickle", "rb") as f:
    model = pickle.load(f)

featuretable = pd.read_parquet("../data/processed/featuretable.parquet")
#laad volledige csv hier in.
#inclusief wat preprocessing enz
#eigelijk zou dit pre-process bestand ergens opgeslagen moeten worden

featuretable["no_show"] = (
    featuretable["no_show"].replace({"no_show": "1", "show": "0"}).astype(int)
)

X, y = featuretable.drop(columns="no_show"), featuretable["no_show"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0, shuffle=False
)

# %% [markdown]
# ## ROC curve

# %%
y_pred = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred[:, 1])
auc_score = roc_auc_score(y_test, y_pred[:, 1])
fig, ax = plt.subplots(figsize=(8, 8))
ax.plot(fpr, tpr, label=f"Hist Gradient Boosting (AUC={round(auc_score, 2)})")
ax.plot([0, 1], [0, 1], label="Random (AUC=0.5)", linestyle="dotted")
ax.legend()
plt.show()

# %% [markdown]
# ## Prediction, recall

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred[:, 1])

fig, ax = plt.subplots(figsize=(8, 8))
ax.plot(thresholds, precision[:-1], label="precision")
ax.plot(thresholds, recall[:-1], label="recall")
ax.legend()
plt.show()

# %%
X_test.resample("1D", level="start")["age"].count().plot.hist(
    title="Number of appointments per day"
)
plt.show()

# %%
'''
total_test_data = X_test.copy()
total_test_data["y_pred"] = y_pred[:, 1]
total_test_data["y_true"] = y_test

test_dates = total_test_data.index.get_level_values("start").date
precisions = []
precisions_random = []
recalls = []
recalls_random = []

for i in range(5, 155, 5):
    prec = []
    prec_random = []
    rec = []
    rec_random = []
    for name, group in total_test_data.groupby(
        total_test_data.index.get_level_values("start").date
    ):
        if name.weekday() not in [5, 6]:
            group_random = group.copy().sample(frac=1)
            group_random["predicted_value"] = 0
            group_random.iloc[:i, group_random.columns.get_loc("predicted_value")] = 1
            prec_random.append(
                precision_score(group_random["y_true"], group_random["predicted_value"])
            )
            rec_random.append(
                recall_score(group_random["y_true"], group_random["predicted_value"])
            )

            group = group.sort_values("y_pred", ascending=False)
            group["predicted_value"] = 0
            group.iloc[:i, group.columns.get_loc("predicted_value")] = 1
            prec.append(precision_score(group["y_true"], group["predicted_value"]))
            rec.append(recall_score(group["y_true"], group["predicted_value"]))
    precisions.append(prec)
    precisions_random.append(prec_random)
    recalls.append(rec)
    recalls_random.append(rec_random)
'''
# Out:
# '\ntotal_test_data = X_test.copy()\ntotal_test_data["y_pred"] = y_pred[:, 1]\ntotal_test_data["y_true"] = y_test\n\ntest_dates = total_test_data.index.get_level_values("start").date\nprecisions = []\nprecisions_random = []\nrecalls = []\nrecalls_random = []\n\nfor i in range(5, 155, 5):\n    prec = []\n    prec_random = []\n    rec = []\n    rec_random = []\n    for name, group in total_test_data.groupby(\n        total_test_data.index.get_level_values("start").date\n    ):\n        if name.weekday() not in [5, 6]:\n            group_random = group.copy().sample(frac=1)\n            group_random["predicted_value"] = 0\n            group_random.iloc[:i, group_random.columns.get_loc("predicted_value")] = 1\n            prec_random.append(\n                precision_score(group_random["y_true"], group_random["predicted_value"])\n            )\n            rec_random.append(\n                recall_score(group_random["y_true"], group_random["predicted_value"])\n            )\n\n            group = group.sort_values("y_pred", ascending=False)\n            group["predicted_value"] = 0\n            group.iloc[:i, group.columns.get_loc("predicted_value")] = 1\n            prec.append(precision_score(group["y_true"], group["predicted_value"]))\n            rec.append(recall_score(group["y_true"], group["predicted_value"]))\n    precisions.append(prec)\n    precisions_random.append(prec_random)\n    recalls.append(rec)\n    recalls_random.append(rec_random)\n'

# %%
print(f"Daily precision: {np.mean(precisions[4])} (+- {np.std(precisions[4])})")
print(f"Daily recall: {np.mean(recalls[4])} (+- {np.std(recalls[4])})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(f"Daily precision: {np.mean(precisions[4])} (+- {np.std(precisions[4])})")
#       2 print(f"Daily recall: {np.mean(recalls[4])} (+- {np.std(recalls[4])})")
#
# NameError: name 'precisions' is not defined

# %%
x_values = range(5, 155, 5)
mean_precision = np.mean(precisions, axis=1)
mean_recall = np.mean(recalls, axis=1)
std_precision = np.std(precisions, axis=1)
std_recall = np.std(recalls, axis=1)

mean_precision_random = np.mean(precisions_random, axis=1)
mean_recall_random = np.mean(recalls_random, axis=1)
std_precision_random = np.std(precisions_random, axis=1)
std_recall_random = np.std(recalls_random, axis=1)
fig, ax = plt.subplots(figsize=(15, 8))

ax.plot(x_values, mean_precision, label="precision")
ax.plot(x_values, mean_recall, label="recall")
ax.fill_between(
    x_values,
    mean_precision - std_precision,
    mean_precision + std_precision,
    label="std precision",
    alpha=0.3,
)
ax.fill_between(
    x_values,
    mean_recall - std_recall,
    mean_recall + std_recall,
    label="std recall",
    alpha=0.3,
)
ax.plot(x_values, mean_precision_random, label="precision_random")
ax.plot(x_values, mean_recall_random, label="recall_random")
ax.fill_between(
    x_values,
    mean_precision_random - std_precision_random,
    mean_precision_random + std_precision_random,
    label="std precision_random",
    alpha=0.3,
)
ax.fill_between(
    x_values,
    mean_recall_random - std_recall_random,
    mean_recall_random + std_recall_random,
    label="std recall_random",
    alpha=0.3,
)
ax.legend()
ax.set_title("Recall and precision for number of people called per day")
ax.set_xlabel("People called per day")
ax.set_ylabel("Total score over all days")
ax.set_ylim((0, 1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 x_values = range(5, 155, 5)
# ----> 2 mean_precision = np.mean(precisions, axis=1)
#       3 mean_recall = np.mean(recalls, axis=1)
#       4 std_precision = np.std(precisions, axis=1)
#
# NameError: name 'precisions' is not defined

# %% [markdown]
# ## Calibration curve

# %%
prob_true, prob_pred = calibration_curve(y_test, y_pred[:, 1], n_bins=20)

fix, ax = plt.subplots()
ax.plot(prob_pred, prob_true, label="model calibration")
ax.plot([0, 1], [0, 1], label="perfect calibration")
ax.set_xlabel("Mean predicted probability")
ax.set_ylabel("Fraction of positives")
ax.set_title("Calibration curve")
ax.legend()
plt.show()

# %% [markdown]
# ## Reliability plot

# %%
y_pred_total = model.predict_proba(X)
print("calibration error:", rp.smECE(y_pred_total[:, 1], y))
fig, ax = rp.rel_diagram(y_pred_total[:, 1], y)
print('test')
fig.show()
# Out:
# calibration error: 0.006439622477141079
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 y_pred_total = model.predict_proba(X)
#       2 print("calibration error:", rp.smECE(y_pred_total[:, 1], y))
# ----> 3 fig, ax = rp.rel_diagram(y_pred_total[:, 1], y)
#       4 print('test')
#       5 fig.show()
#
# File /opt/conda/lib/python3.11/site-packages/relplot/diagrams.py:471, in rel_diagram(f, y, **kwargs)
#     464 def rel_diagram(
#     465     f : npt.ArrayLike,
#     466     y : npt.ArrayLike,
#     467     **kwargs):
#     468     """Compute and plot the reliability diagram for predictions f_i and labels y_i.
#     469     This convenience function simply composes prepare_rel_diagram and plot_rel_diagram.
#     470     """
# --> 471     diagram = prepare_rel_diagram(f, y, **kwargs)
#     472     return plot_rel_diagram(diagram, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/relplot/diagrams.py:253, in prepare_rel_diagram(f, y, plot_confidence_band, plot_bag_lines, num_bootstrap, kde_bandwidth, report_CE, report_CE_std, custom_regressor, kernel, **unused_kwargs)
#     251 outputs["ce"] = ice
#     252 if report_CE_std:
# --> 253     res = scipy.stats.bootstrap(
#     254         (f, y),
#     255         smECE_fast,
#     256         paired=True,
#     257         n_resamples=100,
#     258         method="basic",
#     259         confidence_level=0.95,
#     260     )
#     261     ci = res.confidence_interval
#     262     wid = max(ice - ci.low, ci.high - ice)
#
# File /opt/conda/lib/python3.11/site-packages/scipy/stats/_resampling.py:630, in bootstrap(data, statistic, n_resamples, batch, vectorized, paired, axis, confidence_level, alternative, method, bootstrap_result, random_state)
#     627         resampled_data.append(resample)
#     629     # Compute bootstrap distribution of statistic
# --> 630     theta_hat_b.append(statistic(*resampled_data, axis=-1))
#     631 theta_hat_b = np.concatenate(theta_hat_b, axis=-1)
#     633 # Calculate percentile interval
#
# File /opt/conda/lib/python3.11/site-packages/scipy/stats/_resampling.py:210, in _bootstrap_iv.<locals>.statistic(i, axis, data, unpaired_statistic)
#     208 def statistic(i, axis=-1, data=data_iv, unpaired_statistic=statistic):
#     209     data = [sample[..., i] for sample in data]
# --> 210     return unpaired_statistic(*data, axis=axis)
#
# File /opt/conda/lib/python3.11/site-packages/scipy/stats/_resampling.py:38, in _vectorize_statistic.<locals>.stat_nd(axis, *data)
#      35     data = np.split(z, split_indices)
#      36     return statistic(*data)
# ---> 38 return np.apply_along_axis(stat_1d, 0, z)[()]
#
# File <__array_function__ internals>:200, in apply_along_axis(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numpy/lib/shape_base.py:402, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     400 buff[ind0] = res
#     401 for ind in inds:
# --> 402     buff[ind] = asanyarray(func1d(inarr_view[ind], *args, **kwargs))
#     404 if not isinstance(res, matrix):
#     405     # wrap the array, to preserve subclasses
#     406     buff = res.__array_wrap__(buff)
#
# File /opt/conda/lib/python3.11/site-packages/scipy/stats/_resampling.py:36, in _vectorize_statistic.<locals>.stat_nd.<locals>.stat_1d(z)
#      34 def stat_1d(z):
#      35     data = np.split(z, split_indices)
# ---> 36     return statistic(*data)
#
# File /opt/conda/lib/python3.11/site-packages/relplot/metrics.py:102, in smECE_fast(f, y, eps, return_width)
#      99     recalculate_if_necessary(alpha)
#     100     return alpha < eps or alpha < smooth_ece_interpolated(r_values, alpha)
# --> 102 sigma = search_param(check_smooth_ece, start=1, refine=10)
#     103 if return_width:
#     104     return smooth_ece_interpolated(r_values, sigma), sigma
#
# File /opt/conda/lib/python3.11/site-packages/relplot/metrics.py:65, in search_param(predicate, start, refine)
#      63 for _ in range(refine):
#      64     midpoint = (start + end) / 2
# ---> 65     if predicate(midpoint):
#      66         end = midpoint
#      67     else:
#
# File /opt/conda/lib/python3.11/site-packages/relplot/metrics.py:100, in smECE_fast.<locals>.check_smooth_ece(alpha)
#      98 def check_smooth_ece(alpha):
#      99     recalculate_if_necessary(alpha)
# --> 100     return alpha < eps or alpha < smooth_ece_interpolated(r_values, alpha)
#
# File /opt/conda/lib/python3.11/site-packages/relplot/metrics.py:46, in smooth_ece_interpolated(r_grid, sigma)
#      44 kernel = _get_default_kernel()
#      45 ker = kernel(sigma)
# ---> 46 rs = ker.convolve(r_grid, len(r_grid))
#      47 return np.sum(np.abs(rs)) / len(r_grid)
#
# File /opt/conda/lib/python3.11/site-packages/relplot/kernels.py:131, in ReflectedGaussianKernel.convolve(self, values, eval_points)
#     129 ker = self.kernel_ev(eval_points)
#     130 ext_vals = np.concatenate([np.flip(values)[:-1], values, np.flip(values)[1:]])
# --> 131 return np.convolve(ext_vals, ker, "valid")[eval_points//2 : eval_points//2 + eval_points]
#
# File <__array_function__ internals>:200, in convolve(*args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/numpy/core/numeric.py:851, in convolve(a, v, mode)
#     849 if len(v) == 0:
#     850     raise ValueError('v cannot be empty')
# --> 851 return multiarray.correlate(a, v[::-1], mode)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Feature importance

# %%
from sklearn.inspection import permutation_importance
print(model.importances_mean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 from sklearn.inspection import permutation_importance
# ----> 2 print(model.importances_mean)
#
# AttributeError: 'HistGradientBoostingClassifier' object has no attribute 'importances_mean'

# %%
forest_importances = pd.Series(
    model.feature_importances_, index=model.get_feature_names_out()
).sort_values()

fig, ax = plt.subplots()
ax.barh(
    forest_importances.index,
    forest_importances,
)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 forest_importances = pd.Series(
# ----> 2     model.feature_importances_, index=model.get_feature_names_out()
#       3 ).sort_values()
#       5 fig, ax = plt.subplots()
#       6 ax.barh(
#       7     forest_importances.index,
#       8     forest_importances,
#       9 )
#
# AttributeError: 'HistGradientBoostingClassifier' object has no attribute 'feature_importances_'

# %% [markdown]
# ## Try out predictions

# %%
total_test_data.sort_values("y_pred").head()

# %%
total_test_data.loc[(slice(None), "2022-04-05"), :].sort_values(
    "y_pred", ascending=False
)

# %%
from ipywidgets import FloatSlider, IntSlider, interact

hour = IntSlider(9, 0, 24, 1)
weekday = IntSlider(0, 0, 6, 1)
minutesDuration = IntSlider(30, 5, 120, 5)
prev_no_show = IntSlider(1, 0, 20, 1)
prev_no_show_perc = FloatSlider(0.03, min=0, max=1, step=0.01)
age = IntSlider(20, 0, 100, 1)
dist_umcu = IntSlider(45, 0, 200, 1)
prev_minutes_early = IntSlider(-3, -60, 60, 1)
earlier_appointments = IntSlider(10, 0, 100, 1)
appointments_same_day = IntSlider(1, 0, 7, 1)
appointments_last_days = IntSlider(1, 0, 100, 1)
days_since_created = IntSlider(150, 0, 365, 10)
days_since_last_appointment = IntSlider(21, 0, 365, 1)


@interact
def sim_prediction(
    hour=hour,
    weekday=weekday,
    specialty_code="REV",
    minutesDuration=minutesDuration,
    prev_no_show=prev_no_show,
    prev_no_show_perc=prev_no_show_perc,
    age=age,
    dist_umcu=dist_umcu,
    prev_minutes_early=prev_minutes_early,
    earlier_appointments=earlier_appointments,
    appointments_same_day=appointments_same_day,
    appointments_last_days=appointments_last_days,
    days_since_created=days_since_created,
    days_since_last_appointment=days_since_last_appointment,
    poli_ident="Consult",
):
    prediction_df = pd.DataFrame(
        {
            "hour": hour,
            "weekday": weekday,
            "specialty_code": specialty_code,
            "minutesDuration": minutesDuration,
            "prev_no_show": prev_no_show,
            "prev_no_show_perc": prev_no_show_perc,
            "age": age,
            "dist_umcu": dist_umcu,
            "prev_minutes_early": prev_minutes_early,
            "earlier_appointments": earlier_appointments,
            "appointments_same_day": appointments_same_day,
            "appointments_last_days": appointments_last_days,
            "days_since_created": days_since_created,
            "days_since_last_appointment": days_since_last_appointment,
            "poli_ident": poli_ident,
        },
        index=[0],
    )

    print(f"Predicted value is: {model.predict_proba(prediction_df)[:,1]}")
